# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
from __future__ import unicode_literals

import logging
import rasa_core

from rasa_core.run import serve_application
from rasa_core import config
from rasa_core.agent import Agent
#from rasa_core.channels.console import ConsoleInputChannel
from rasa_core.interpreter import RegexInterpreter
from rasa_core.policies.keras_policy import KerasPolicy
from rasa_core.policies.memoization import MemoizationPolicy
from rasa_core.interpreter import RasaNLUInterpreter

logger = logging.getLogger(__name__)


def run_weather_online(input_channel, interpreter,
                          domain_file="weather_domain.yml",
                          training_data_file='data/stories.md'):
            agent = Agent('weather_domain.yml', policies = [MemoizationPolicy(max_history=2), KerasPolicy(max_history=4)])
            data = agent.load_data(training_data_file)
            agent.train(data)
            rasa_core.run.serve_application(agent ,'endpoints.yml')
            #interactive.run_interactive_learning(agent, training_data_file)
            return agent 

if __name__ == '__main__':
    logging.basicConfig(level="INFO")
    nlu_interpreter = RasaNLUInterpreter('./models/nlu/default/weatherbot')
    #run_weather_online(ConsoleInputChannel(), nlu_interpreter)
    run_weather_online('endpoints.yml', nlu_interpreter)
# Out:
# INFO:rasa_nlu.components:Added 'SpacyNLP' to component cache. Key 'SpacyNLP-en'.
# Processed Story Blocks: 100%|██████████| 3/3 [00:00<00:00, 568.49it/s, # trackers=1]
# Processed Story Blocks: 100%|██████████| 3/3 [00:00<00:00, 345.82it/s, # trackers=3]
# Processed Story Blocks: 100%|██████████| 3/3 [00:00<00:00, 215.64it/s, # trackers=4]
# Processed Story Blocks: 100%|██████████| 3/3 [00:00<00:00, 205.62it/s, # trackers=4]
# Processed actions: 20it [00:00, 510.46it/s, # examples=16]
# WARNING:tensorflow:From /Users/admin/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /Users/admin/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /Users/admin/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/backend.py:4010: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /Users/admin/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/backend.py:4010: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# INFO:rasa_core.policies.keras_policy:Fitting model with 46 total samples and a validation split of 0.1
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# masking (Masking)            (None, 4, 17)             0
# _________________________________________________________________
# lstm (LSTM)                  (None, 32)                6400
# _________________________________________________________________
# dense (Dense)                (None, 12)                396
# _________________________________________________________________
# activation (Activation)      (None, 12)                0
# =================================================================
# Total params: 6,796
# Trainable params: 6,796
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:From /Users/admin/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /Users/admin/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/100
# 46/46 [==============================] - 2s 42ms/sample - loss: 2.4313 - acc: 0.2174
# Epoch 2/100
# 46/46 [==============================] - 0s 402us/sample - loss: 2.3938 - acc: 0.2174
# Epoch 3/100
# 46/46 [==============================] - 0s 404us/sample - loss: 2.3391 - acc: 0.3478
# Epoch 4/100
# 46/46 [==============================] - 0s 429us/sample - loss: 2.3271 - acc: 0.2826
# Epoch 5/100
# 46/46 [==============================] - 0s 420us/sample - loss: 2.2896 - acc: 0.3043
# Epoch 6/100
# 46/46 [==============================] - 0s 412us/sample - loss: 2.2609 - acc: 0.3696
# Epoch 7/100
# 46/46 [==============================] - 0s 434us/sample - loss: 2.2505 - acc: 0.4130
# Epoch 8/100
# 46/46 [==============================] - 0s 414us/sample - loss: 2.2232 - acc: 0.4130
# Epoch 9/100
# 46/46 [==============================] - 0s 407us/sample - loss: 2.1743 - acc: 0.3696
# Epoch 96/100
# 46/46 [==============================] - 0s 419us/sample - loss: 1.0628 - acc: 0.6957
# Epoch 97/100
# 46/46 [==============================] - 0s 439us/sample - loss: 1.0139 - acc: 0.7391
# Epoch 98/100
# 46/46 [==============================] - 0s 420us/sample - loss: 1.0177 - acc: 0.6739
# Epoch 99/100
# 46/46 [==============================] - 0s 435us/sample - loss: 1.0264 - acc: 0.6739
# Epoch 100/100
# 46/46 [==============================] - 0s 442us/sample - loss: 1.0391 - acc: 0.6739
# INFO:rasa_core.policies.keras_policy:Done fitting keras policy model
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/rasa_core/run.py in _create_single_channel(channel, credentials)
#      63         try:
# ---> 64             input_channel_class = utils.class_from_module_path(channel)
#      65             return input_channel_class.from_credentials(credentials)
#
# ~/anaconda3/lib/python3.7/site-packages/rasa_core/utils.py in class_from_module_path(module_path)
#      62         module_name, _, class_name = module_path.rpartition('.')
# ---> 63         m = importlib.import_module(module_name)
#      64         # get the class, will raise AttributeError if class cannot be found
#
# ~/anaconda3/lib/python3.7/importlib/__init__.py in import_module(name, package)
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#
# ~/anaconda3/lib/python3.7/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# ~/anaconda3/lib/python3.7/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# ~/anaconda3/lib/python3.7/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'endpoints'
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# <ipython-input-1-f95112b7cd64> in <module>
#      33     nlu_interpreter = RasaNLUInterpreter('./models/nlu/default/weatherbot')
#      34     #run_weather_online(ConsoleInputChannel(), nlu_interpreter)
# ---> 35     run_weather_online('endpoints.yml', nlu_interpreter)
#      36
#      37
#
# <ipython-input-1-f95112b7cd64> in run_weather_online(input_channel, interpreter, domain_file, training_data_file)
#      25             data = agent.load_data(training_data_file)
#      26             agent.train(data)
# ---> 27             rasa_core.run.serve_application(agent ,'endpoints.yml')
#      28             #interactive.run_interactive_learning(agent, training_data_file)
#      29             return agent
#
# ~/anaconda3/lib/python3.7/site-packages/rasa_core/run.py in serve_application(initial_agent, channel, port, credentials_file, cors, auth_token, enable_api, jwt_secret, jwt_method)
#     137         channel = "cmdline"
#     138
# --> 139     input_channels = create_http_input_channels(channel, credentials_file)
#     140
#     141     http_server = start_server(input_channels, cors, auth_token,
#
# ~/anaconda3/lib/python3.7/site-packages/rasa_core/run.py in create_http_input_channels(channel, credentials_file)
#      48
#      49     if channel:
# ---> 50         return [_create_single_channel(channel, all_credentials.get(channel))]
#      51     else:
#      52         return [_create_single_channel(c, k)
#
# ~/anaconda3/lib/python3.7/site-packages/rasa_core/run.py in _create_single_channel(channel, credentials)
#      70                 "make sure the mentioned channel is not misspelled. "
#      71                 "If you are creating your own channel, make sure it "
# ---> 72                 "is a proper name of a class in a module.".format(channel))
#      73
#      74
#
# Exception: Failed to find input channel class for 'endpoints.yml'. Unknown input channel. Check your credentials configuration to make sure the mentioned channel is not misspelled. If you are creating your own channel, make sure it is a proper name of a class in a module.
